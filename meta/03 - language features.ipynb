# %%
from meta_stuff import process_set
# %matplotlib inline

# %% [markdown]
# # Word frequency
# Random-effects meta-analysis of the effects of word frequency in 9 datasets. Word frequency is operationalized as the Lg10WF measure from the SUBTLEX_US norms (Brysbaert & New, 2009). The model is identical in all datasets, and contains only log-transformed word frequencies and standard confound regressors (speech, motion, and temporal filtering).

# %%
effects = {
    "subtlexusfrequencyLg10Wf": ["AqQxk", "Ma40P", "wjNOy", "9L2kY", "97pXv", "wkVjV", "M4jV2",
                                 "A25Pv", "wkV5V", "9BqG5"]
}
freq_map = process_set("word_freq", effects=effects, download=False, exclude=['SherlockMovie'], camel_case=False)
# Out:
# Meta-analyzing 9 studies for effect 'subtlexusfrequencyLg10Wf'.

# %% [markdown]
# # Lexical effects — big model
# An expanded model that includes 7 different lexical variables. This is meant to approximate the model reported in Yarkoni et al. (2008) for a reading paradigm, though the variables aren't identical, as some weren't available and others don't make sense in the context of auditory presentation.

# %%
eff_names = ['massiveauditorylexicaldecisionNumphones', 'massiveauditorylexicaldecisionPhonlev',
             'subtlexusfrequencyLg10Wf', 'speech', 'concretenessConc.M', 'textLength',
             'massiveauditorylexicaldecisionDuration', 'massiveauditorylexicaldecisionNumsylls']
ids = ["AxBPb", "wJ3rm", "M37W8", "AYyjb", "9Bq37", "MD1B4", "wQDXz", "w0gXN", "wK2z5", "wQDpd"]
effects = {n: ids for n in eff_names}

ma_maps = process_set("lexical_effects", effects=effects, download=False, exclude=['SherlockMovie'], camel_case=False)
# Out:
# ...
# Meta-analyzing 9 studies for effect 'concretenessConc.M'.
# Meta-analyzing 9 studies for effect 'massiveauditorylexicaldecisionDuration'.
# Meta-analyzing 9 studies for effect 'massiveauditorylexicaldecisionNumphones'.
# Meta-analyzing 9 studies for effect 'massiveauditorylexicaldecisionNumsylls'.
# Meta-analyzing 9 studies for effect 'massiveauditorylexicaldecisionPhonlev'.
# Meta-analyzing 9 studies for effect 'speech'.
# Meta-analyzing 9 studies for effect 'subtlexusfrequencyLg10Wf'.
# Meta-analyzing 9 studies for effect 'textLength'.

# %% [markdown]
# # Lancaster sensorimotor norms
# Meta-analyses of the different dimensions found in the [Lancaster sensorimotor norms](https://link.springer.com/article/10.3758/s13428-019-01316) dataset.

# %%
json_data = {"lancastersensorimotornorms_Visual.mean": {"HealthyBrainNetwork": {"movieDM": "9BbWn"}, "SchematicNarrative": {"perception": "MDzGo"}, "Raiders": {"raiders": "wQorl"}, "Life": {"life": "w0v3D"}, "ParanoiaStory": {"story": "wK3Bj"}, "Sherlock": {"sherlockPart1": "Aob5m"}, "SherlockMerlin": {"MerlinMovie": "Ar65Q", "SherlockMovie": "MzqJ5"}, "LearningTemporalStructure": {"movie": "MD1Gm"}, "Budapest": {"movie": "AqQm8"}}, "lancastersensorimotornorms_Auditory.mean": {"HealthyBrainNetwork": {"movieDM": "M8Lry"}, "SchematicNarrative": {"perception": "AVr1k"}, "Raiders": {"raiders": "A1GYY"}, "Life": {"life": "wOVKP"}, "ParanoiaStory": {"story": "MXmXD"}, "Sherlock": {"sherlockPart1": "Abn5Z"}, "SherlockMerlin": {"MerlinMovie": "MnP5g", "SherlockMovie": "wWVO5"}, "LearningTemporalStructure": {"movie": "wQDrk"}, "Budapest": {"movie": "Ma4P1"}}, "lancastersensorimotornorms_Olfactory.mean": {"HealthyBrainNetwork": {"movieDM": "MGbx3"}, "SchematicNarrative": {"perception": "Aqb5O"}, "Raiders": {"raiders": "Maq5J"}, "Life": {"life": "wjv5X"}, "ParanoiaStory": {"story": "9LqDV"}, "Sherlock": {"sherlockPart1": "97voB"}, "SherlockMerlin": {"MerlinMovie": "wkK53", "SherlockMovie": "M4nQz"}, "LearningTemporalStructure": {"movie": "w0g33"}, "Budapest": {"movie": "wjN40"}}, "lancastersensorimotornorms_Haptic.mean": {"HealthyBrainNetwork": {"movieDM": "MNW0Z"}, "SchematicNarrative": {"perception": "M5Q0P"}, "Raiders": {"raiders": "9eK5k"}, "Life": {"life": "AZyB2"}, "ParanoiaStory": {"story": "MvbQb"}, "Sherlock": {"sherlockPart1": "Mmvq3"}, "SherlockMerlin": {"MerlinMovie": "Mp8xb", "SherlockMovie": "wyDod"}, "LearningTemporalStructure": {"movie": "wK2B7"}, "Budapest": {"movie": "9L2lz"}}, "lancastersensorimotornorms_Gustatory.mean": {"HealthyBrainNetwork": {"movieDM": "wgjXY"}, "SchematicNarrative": {"perception": "MPK73"}, "Raiders": {"raiders": "A6mPp"}, "Life": {"life": "wlyGp"}, "ParanoiaStory": {"story": "AxkKD"}, "Sherlock": {"sherlockPart1": "wJJ7p"}, "SherlockMerlin": {"MerlinMovie": "M34Xz", "SherlockMovie": "AYXYr"}, "LearningTemporalStructure": {"movie": "Aop5J"}, "Budapest": {"movie": "97pWO"}}, "lancastersensorimotornorms_Interoceptive.mean": {"HealthyBrainNetwork": {"movieDM": "MDzpo"}, "SchematicNarrative": {"perception": "wQoel"}, "Raiders": {"raiders": "w0vVD"}, "Life": {"life": "wK37j"}, "ParanoiaStory": {"story": "Aoblm"}, "Sherlock": {"sherlockPart1": "A6mPQ"}, "SherlockMerlin": {"MerlinMovie": "wlyGX", "SherlockMovie": "AxkKb"}, "LearningTemporalStructure": {"movie": "A6oKd"}, "Budapest": {"movie": "wkV2y"}}, "lancastersensorimotornorms_Foot_leg.mean": {"HealthyBrainNetwork": {"movieDM": "M34X8"}, "SchematicNarrative": {"perception": "AYXYb"}, "Raiders": {"raiders": "9Bb77"}, "Life": {"life": "MDzp4"}, "ParanoiaStory": {"story": "wQoez"}, "Sherlock": {"sherlockPart1": "w0vVN"}, "SherlockMerlin": {"MerlinMovie": "wK375", "SherlockMovie": "Aobla"}, "LearningTemporalStructure": {"movie": "wl85e"}, "Budapest": {"movie": "M4jXg"}}, "lancastersensorimotornorms_Hand_arm.mean": {"HealthyBrainNetwork": {"movieDM": "Mzqrj"}, "SchematicNarrative": {"perception": "AdpVB"}, "Raiders": {"raiders": "M8LG3"}, "Life": {"life": "AVrxa"}, "ParanoiaStory": {"story": "A1G16"}, "Sherlock": {"sherlockPart1": "wOVPd"}, "SherlockMerlin": {"MerlinMovie": "MXmPK", "SherlockMovie": "AbndV"}, "LearningTemporalStructure": {"movie": "AxBl6"}, "Budapest": {"movie": "A251p"}}, "lancastersensorimotornorms_Head.mean": {"HealthyBrainNetwork": {"movieDM": "wWVJr"}, "SchematicNarrative": {"perception": "9EW70"}, "Raiders": {"raiders": "MGb4l"}, "Life": {"life": "AqbYb"}, "ParanoiaStory": {"story": "MaqV4"}, "Sherlock": {"sherlockPart1": "wjvqP"}, "SherlockMerlin": {"MerlinMovie": "9Lq4p", "SherlockMovie": "97vZe"}, "LearningTemporalStructure": {"movie": "wJ3Yb"}, "Budapest": {"movie": "MNQJl"}}, "lancastersensorimotornorms_Mouth.mean": {"HealthyBrainNetwork": {"movieDM": "M4nmG"}, "SchematicNarrative": {"perception": "A2YmL"}, "Raiders": {"raiders": "MNW4N"}, "Life": {"life": "M5Qm6"}, "ParanoiaStory": {"story": "9eKb6"}, "Sherlock": {"sherlockPart1": "AZy01"}, "SherlockMerlin": {"MerlinMovie": "MvbK7", "SherlockMovie": "Mmvlx"}, "LearningTemporalStructure": {"movie": "M37DP"}, "Budapest": {"movie": "M55Px"}}, "lancastersensorimotornorms_Torso.mean": {"HealthyBrainNetwork": {"movieDM": "wyDz0"}, "SchematicNarrative": {"perception": "MR2lg"}, "Raiders": {"raiders": "wgjWR"}, "Life": {"life": "MPKvE"}, "ParanoiaStory": {"story": "A6m4Q"}, "Sherlock": {"sherlockPart1": "wly6X"}, "SherlockMerlin": {"MerlinMovie": "Axkrb", "SherlockMovie": "wJJ4m"}, "LearningTemporalStructure": {"movie": "AYybj"}, "Budapest": {"movie": "9eya7"}}}
process_set("sensorimotor_norms", json_data=json_data, download=True, exclude=['SherlockMovie']);
# Out:
# defaultdict(<class 'list'>, {'lancastersensorimotornorms_Visual.mean': ['9BbWn', 'MDzGo', 'wQorl', 'w0v3D', 'wK3Bj', 'Aob5m', 'Ar65Q', 'MzqJ5', 'MD1Gm', 'AqQm8'], 'lancastersensorimotornorms_Auditory.mean': ['M8Lry', 'AVr1k', 'A1GYY', 'wOVKP', 'MXmXD', 'Abn5Z', 'MnP5g', 'wWVO5', 'wQDrk', 'Ma4P1'], 'lancastersensorimotornorms_Olfactory.mean': ['MGbx3', 'Aqb5O', 'Maq5J', 'wjv5X', '9LqDV', '97voB', 'wkK53', 'M4nQz', 'w0g33', 'wjN40'], 'lancastersensorimotornorms_Haptic.mean': ['MNW0Z', 'M5Q0P', '9eK5k', 'AZyB2', 'MvbQb', 'Mmvq3', 'Mp8xb', 'wyDod', 'wK2B7', '9L2lz'], 'lancastersensorimotornorms_Gustatory.mean': ['wgjXY', 'MPK73', 'A6mPp', 'wlyGp', 'AxkKD', 'wJJ7p', 'M34Xz', 'AYXYr', 'Aop5J', '97pWO'], 'lancastersensorimotornorms_Interoceptive.mean': ['MDzpo', 'wQoel', 'w0vVD', 'wK37j', 'Aoblm', 'A6mPQ', 'wlyGX', 'AxkKb', 'A6oKd', 'wkV2y'], 'lancastersensorimotornorms_Foot_leg.mean': ['M34X8', 'AYXYb', '9Bb77', 'MDzp4', 'wQoez', 'w0vVN', 'wK375', 'Aobla', 'wl85e', 'M4jXg'], 'lancastersens
# ...

# %% [markdown]
# # Entropy and surprisal
# Meta-analyses for separate entropy and surprisal models, computed on next-word predictions generated using a pretrained BERT model. Both models include a speech covariate (i.e., speech vs. no speech).
#
# Note: all analyses involving entropy and surprisal are based on 8 rather than 9 datasets because of issues with SchematicNarratives (see https://github.com/neuroscout/neuroscout/issues/772).

# %%
effects = {
    'BERTLMPre25Entropy': ["MNQGZ", "M55kP", "9eyVk", "AZ4E2", "Mv3Xb", "Mm3K3", "MpDzb", "wy2Wd", "wJ324"],
    'BERTLMPre25Surprisal': ["MRa8R", "wgy3Y", "MPqz3", "A6oXp", "wl80p", "AxBnD", "wJ3Dp", "Aoprm", "AxBvK"]
}
process_set('entropy', effects=effects, camel_case=False, download=True, exclude=['SherlockMovie']);
# Out:
# ...
# Meta-analyzing 8 studies for effect 'BERTLMPre25Entropy'.
# Meta-analyzing 8 studies for effect 'BERTLMPre25Surprisal'.

# %% [markdown]
# # Surprisal and entropy together
# Meta-analysis of models including both surprisal and entropy (as well as a speech covariate).

# %%
json_data = {"speech+BERTLM_pre_25_surprisal+BERTLM_pre_25_entropy+subtlexusfrequency_Lg10WF+text_length": {"HealthyBrainNetwork": {"movieDM": "97pae"}, "SchematicNarrative": {}, "studyforrest": {}, "Raiders": {"raiders": "wkVr4"}, "Life": {"life": "M4jEG"}, "ParanoiaStory": {"story": "A25nL"}, "Sherlock": {"sherlockPart1": "MNQVN"}, "SherlockMerlin": {"MerlinMovie": "M55G6", "SherlockMovie": "9eyB6"}, "LearningTemporalStructure": {"movie": "AZ4L1"}, "Budapest": {"movie": "M370o"}}, "BERTLM_pre_25_surprisal+BERTLM_pre_25_entropy": {"HealthyBrainNetwork": {"movieDM": "Mnkoj"}, "SchematicNarrative": {}, "studyforrest": {}, "Raiders": {"raiders": "wWybr"}, "Life": {"life": "9Edx0"}, "ParanoiaStory": {"story": "MGv0l"}, "Sherlock": {"sherlockPart1": "AqQOb"}, "SherlockMerlin": {"MerlinMovie": "Ma4x4", "SherlockMovie": "wjNoP"}, "LearningTemporalStructure": {"movie": "9L2dp"}, "Budapest": {"movie": "AYyPe"}}}
model = list(json_data.keys())[1]
eff_names = ['BERTLMPre25Entropy', 'BERTLMPre25Surprisal']
ids = []
[ids.extend(ds.values()) for ds in json_data[model].values()]
effects = {eff: ids for eff in eff_names}

process_set('entropy-surprisal', effects, download=True, camel_case=False, exclude=['sherlockMovie']);
# Out:
# ...
# Meta-analyzing 8 studies for effect 'BERTLMPre25Entropy'.
# Meta-analyzing 8 studies for effect 'BERTLMPre25Surprisal'.

# %% [markdown]
# # Surprisal and entropy plus lexical covariates
# Meta-analysis of models containing surprisal, entropy, and several additional covariates. The assumption is that much of the variance in surprisal and entropy is likely to be shared with lexical features (e.g., low-frequency words are bound to also be low on surprisal).

# %%
json_data = {"speech+BERTLM_pre_25_surprisal+BERTLM_pre_25_entropy+subtlexusfrequency_Lg10WF+text_length": {"HealthyBrainNetwork": {"movieDM": "97pae"}, "SchematicNarrative": {}, "studyforrest": {}, "Raiders": {"raiders": "wkVr4"}, "Life": {"life": "M4jEG"}, "ParanoiaStory": {"story": "A25nL"}, "Sherlock": {"sherlockPart1": "MNQVN"}, "SherlockMerlin": {"MerlinMovie": "M55G6", "SherlockMovie": "9eyB6"}, "LearningTemporalStructure": {"movie": "AZ4L1"}, "Budapest": {"movie": "M370o"}}, "BERTLM_pre_25_surprisal+BERTLM_pre_25_entropy": {"HealthyBrainNetwork": {"movieDM": "Mnkoj"}, "SchematicNarrative": {}, "studyforrest": {}, "Raiders": {"raiders": "wWybr"}, "Life": {"life": "9Edx0"}, "ParanoiaStory": {"story": "MGv0l"}, "Sherlock": {"sherlockPart1": "AqQOb"}, "SherlockMerlin": {"MerlinMovie": "Ma4x4", "SherlockMovie": "wjNoP"}, "LearningTemporalStructure": {"movie": "9L2dp"}, "Budapest": {"movie": "AYyPe"}}}
model = list(json_data.keys())[0]
eff_names = ['speech', 'textLength', 'BERTLMPre25Entropy', 'BERTLMPre25Surprisal', 'subtlexusfrequencyLg10Wf']
ids = []
[ids.extend(ds.values()) for ds in json_data[model].values()]
effects = {eff: ids for eff in eff_names}

process_set('entropy-surprisal-covars', effects, download=True, camel_case=False, exclude=['SherlockMovie']);
# Out:
# ...
# Meta-analyzing 8 studies for effect 'BERTLMPre25Entropy'.
# Meta-analyzing 8 studies for effect 'BERTLMPre25Surprisal'.
# Meta-analyzing 8 studies for effect 'speech'.
# Meta-analyzing 8 studies for effect 'subtlexusfrequencyLg10Wf'.
# Meta-analyzing 8 studies for effect 'textLength'.
