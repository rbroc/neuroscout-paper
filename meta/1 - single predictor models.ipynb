# %%
from meta import analyze_collection
from nilearn.datasets import load_mni152_brain_mask
from nilearn import plotting as niplt
from pyns import Neuroscout
from pathlib import Path
import json
# %matplotlib inline
# Out:
# ERROR:duecredit:Failed to import duecredit due to No module named 'duecredit'

# %%
import nimare

# %% [markdown]
# # Single-predictor models for key features
# Meta-analyses of 8 different features: 4 visual categories, 2 low level visual features and 2 auditory features
#
#
# Each model contains only the target feature plus standard nuisance covariates.

# %%
single_predictors = json.load(open('../analyses/models/single_predictor.json'))
ns = Neuroscout()

# %% [markdown]
# # Meta-Analysis

# %%
for label in ['brightness', 'shot_change']:
    analyze_collection(
        single_predictors[label], 
        collection_kwargs={'estimator': 'afni'},
        plot_kwargs=dict(vmax=18, cut_coords=range(-25, 55, 16), threshold=3.29)
    )
# Out:
# INFO:nimare.extract.utils:Dataset created in /home/alejandro/repos/neuroscout-paper/meta/images/brightness
# INFO:nimare.utils:Shared path detected: '/home/alejandro/repos/neuroscout-paper/meta/images/brightness/'
# INFO:nimare.utils:Shared path detected: '/home/alejandro/repos/neuroscout-paper/meta/images/brightness/'
# WARNING:nimare.base:Masking out 7754 additional voxels. The updated masker is available in the Estimator.masker attribute.
# meta-analyzing 20 for brightness
# INFO:nimare.extract.utils:Dataset created in /home/alejandro/repos/neuroscout-paper/meta/images/shotChange
# INFO:nimare.utils:Shared path detected: '/home/alejandro/repos/neuroscout-paper/meta/images/shotChange/'
# INFO:nimare.utils:Shared path detected: '/home/alejandro/repos/neuroscout-paper/meta/images/shotChange/'
# WARNING:nimare.base:Masking out 7210 additional voxels. The updated masker is available in the Estimator.masker attribute.
# meta-analyzing 10 for shotChange

# %%
auditory = ['speech', 'rms']
for label in auditory:
    analyze_collection(
        single_predictors[label], 
        collection_kwargs={'estimator': 'afni'},
        plot_kwargs=dict(vmax=18, cut_coords=range(-25, 55, 16), threshold=3.29)
    )
# Out:
# INFO:nimare.extract.utils:Dataset created in /home/alejandro/repos/neuroscout-paper/meta/images/speech
# INFO:nimare.utils:Shared path detected: '/home/alejandro/repos/neuroscout-paper/meta/images/speech/'
# INFO:nimare.utils:Shared path detected: '/home/alejandro/repos/neuroscout-paper/meta/images/speech/'
# WARNING:nimare.base:Masking out 7754 additional voxels. The updated masker is available in the Estimator.masker attribute.
# meta-analyzing 20 for speech
# INFO:nimare.extract.utils:Dataset created in /home/alejandro/repos/neuroscout-paper/meta/images/rms
# INFO:nimare.utils:Shared path detected: '/home/alejandro/repos/neuroscout-paper/meta/images/rms/'
# INFO:nimare.utils:Shared path detected: '/home/alejandro/repos/neuroscout-paper/meta/images/rms/'
# WARNING:nimare.base:Masking out 7754 additional voxels. The updated masker is available in the Estimator.masker attribute.
# meta-analyzing 21 for rms

# %%
clarifai = ['text',  'landscape', 'tool']
for label in clarifai:
    analyze_collection(
        single_predictors[label], 
        collection_kwargs={'estimator': 'afni'},
        plot_kwargs=dict(vmax=18, cut_coords=range(-25, 55, 16), threshold=3.29)
    )
# Out:
# INFO:nimare.extract.utils:Dataset created in /home/alejandro/repos/neuroscout-paper/meta/images/text
# INFO:nimare.utils:Shared path detected: '/home/alejandro/repos/neuroscout-paper/meta/images/text/'
# INFO:nimare.utils:Shared path detected: '/home/alejandro/repos/neuroscout-paper/meta/images/text/'
# WARNING:nimare.base:Masking out 7754 additional voxels. The updated masker is available in the Estimator.masker attribute.
# meta-analyzing 20 for text
# INFO:nimare.extract.utils:Dataset created in /home/alejandro/repos/neuroscout-paper/meta/images/landscape
# INFO:nimare.utils:Shared path detected: '/home/alejandro/repos/neuroscout-paper/meta/images/landscape/'
# INFO:nimare.utils:Shared path detected: '/home/alejandro/repos/neuroscout-paper/meta/images/landscape/'
# WARNING:nimare.base:Masking out 7754 additional voxels. The updated masker is available in the Estimator.masker attribute.
# meta-analyzing 20 for landscape
# INFO:nimare.extract.utils:Dataset created in /home/alejandro/repos/neuroscout-paper/meta/images/tool
# INFO:nimare.utils:Shared path detected: '/home/alejandro/repos/neuroscout-paper/meta/images/tool/'
# INFO:nimare.utils:Shared path detected: '/home/alejandro/repos/neuroscout-paper/meta/images/tool/'
# WARNING:nimare.base:Masking out 7754 additional voxels. The updated masker is available in the Estimator.masker attribute.
# meta-analyzing 20 for tool

# %% [markdown]
# ### Figure 4 meta-analytic maps

# %%
text_img = analyze_collection(
    single_predictors['text'], 
    collection_kwargs={'estimator': 'afni'},
    plot_kwargs=dict(vmax=18, cut_coords=[-10], threshold=3.29)
)[0]
# Out:
# INFO:nimare.utils:Shared path detected: '/home/alejandro/repos/neuroscout-paper/meta/images/text/'
# WARNING:nimare.base:Masking out 7754 additional voxels. The updated masker is available in the Estimator.masker attribute.
# meta-analyzing 20 for text

# %%
building_img = analyze_collection(
    single_predictors['building'], 
    collection_kwargs={'estimator': 'afni'},
    plot_kwargs=dict(vmax=18, threshold=3.29, cut_coords=[-12])
)[0]
# Out:
# INFO:nimare.extract.utils:Dataset created in /home/alejandro/repos/neuroscout-paper/meta/images/building
# INFO:nimare.utils:Shared path detected: '/home/alejandro/repos/neuroscout-paper/meta/images/building/'
# INFO:nimare.utils:Shared path detected: '/home/alejandro/repos/neuroscout-paper/meta/images/building/'
# WARNING:nimare.base:Masking out 7754 additional voxels. The updated masker is available in the Estimator.masker attribute.
# meta-analyzing 20 for building

# %%
rms_img = analyze_collection(
    single_predictors['rms'], 
    collection_kwargs={'estimator': 'afni'},
    plot_kwargs=dict(vmax=18, cut_coords=[6], threshold=3.29)
)[0]
# Out:
# INFO:nimare.utils:Shared path detected: '/home/alejandro/repos/neuroscout-paper/meta/images/rms/'
# WARNING:nimare.base:Masking out 7754 additional voxels. The updated masker is available in the Estimator.masker attribute.
# meta-analyzing 21 for rms
