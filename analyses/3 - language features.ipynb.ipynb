# %% [markdown]
# # 3 - Language Models
#
# Models investigating the effect of spoken frequency, and concretneess, controlling for using word norms, including orthographic frequency norms and prescence of speech. </br>

# %%
from create import create_models
from pyns import Neuroscout
from matplotlib import pyplot as plt
from pathlib import Path
import sys
sys.path.append("..") 
from utils import dump_collection, load_collection

# %matplotlib inline
# Out:
# /home/alejandro/anaconda3/lib/python3.7/site-packages/nilearn/datasets/__init__.py:89: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   "Numpy arrays.", FutureWarning)

# %%
api = Neuroscout()

# %% [markdown]
# ## Define predictors and confounds

# %%
predictors = [
    'subtlexusfrequency_Lg10WF', 'speech', 'massiveauditorylexicaldecision_PhonLev', 'text_length', 
    'massiveauditorylexicaldecision_NumSylls', 'massiveauditorylexicaldecision_NumPhones', 
    'massiveauditorylexicaldecision_Duration', 'concreteness_Conc.M'
]
transform_variables = list(set(predictors) - set(['speech']))
datasets = api.datasets.get() # Get all Neuroscout datasets

# %%
confounds = ['a_comp_cor_00', 'a_comp_cor_01', 'a_comp_cor_02', 'a_comp_cor_03', 'a_comp_cor_04', 'a_comp_cor_05', 'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z']

# %%
filename = Path('models') / 'lexical_variables.json'
language_models = load_collection(filename) # Load instead of re-running

# %% [markdown]
# ## Create models

# %%
transformations = [
    {"Name": "Scale", "Demean": True, "Rescale": True, "ReplaceNA": "after", "Input": [p],"Output": [p]} 
    for p in transform_variables
    ]

# %%
name = name = '+'.join(predictors)
language_models = {}
# language_models[name] = create_models(name=name,
#     predictors=predictors, confounds=confounds, datasets=datasets, transformations=transformations)

# %%
analysis = language_models[name][0]['analysis']
analysis.generate_report(run_id=analysis.runs[0]) 
analysis.plot_report(plot_type='design_matrix_plot')
# Out:
# <div id="altair-viz-1"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt){
#     const outputDiv = document.getElementById("altair-viz-1");
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.0.0?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = paths[lib];
#         s.async = true;
#         s.onload = () => resolve(paths[lib]);
#         s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#     } else {
#       loadScript("vega")
#         .then(() => loadScript("vega-lite"))
#         .then(() => loadScript("vega-embed"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "config": {"scale": {"bandPaddingInner": 0.0}, "view": {"continuousHeight": 300, "continuousWidth": 400}}, "data": {"name": "data-b471e2eef2329ad842eafa26fe0b515a"}, "datasets": {"data-b471e2eef2329ad842eafa26fe0b515a": [{"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 0, "value": -4.109397845668746e-12}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 1, "value": 1.0165519568969086e-11}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 2, "value": -2.448056131907903e-11}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 3, "value": 5.707381890184913e-11}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 4, "value": -1.2760983380615576e-10}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 5, "value": 2.6899029494022947e-10}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 6, "value": -5.160082967562063e-10}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 7, "value": 8.209181103912882e-10}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 8, "value": -6.910202519509775e-10}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 9, "value": -2.1174862331684515e-09}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 10, "value": 1.5900901580317783e-08}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 11, "value": -6.838650843051768e-08}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 12, "value": 2.4667393429463194e-07}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 13, "value": -8.127288524831545e-07}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 14, "value": 2.528539180240452e-06}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 15, "value": -7.542859997432457e-06}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 16, "value": 2.178970447555816e-05}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 17, "value": -6.13503592478346e-05}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 18, "value": 0.00016899483492723312}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 19, "value": -0.00044730103472488913}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 20, "value": 0.0011076522792162233}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 21, "value": -0.002495765912618743}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 22, "value": 0.039708620184422366}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 23, "value": 0.14014077011826992}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 24, "value": 0.09582722289457853}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 25, "value": -0.0020016904034831488}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 26, "value": -0.03923196353705078}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 27, "value": -0.3769980816651683}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 28, "value": -0.6828315666336859}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 29, "value": -0.5934651638543804}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 30, "value": -0.2890657421374448}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 31, "value": -0.05282858085900367}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 32, "value": 0.02421104622639359}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 33, "value": -0.048868436618823036}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 34, "value": -0.0398618769734428}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 35, "value": 0.021804710049315952}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 36, "value": 0.0249424483921322}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 37, "value": 0.01908365928985856}, {"regressor": "subtlexusfrequency_Lg10WF", "scan_number": 38, "value": 0.011617663300774766}, {"regressor": "subt ...

# %%
# dump_collection(language_models, filename)

# %% [markdown]
# ## Compile models

# %%
# Compile analyses
# for analysis_dict in language_models[name]:
#     analysis = analysis_dict['analysis']
#     if analysis.get_status()['status'] in 'DRAFT':
#         analysis.compile()
