# %% [markdown]
# # Single predictor models
# Single predictor models investigating the effect of a range of lower- and higher-level visual and auditory predictors. Analyses are run using Neuroscout's pyNS interaface for the Neuroscout API. Identical analyses are specified for each dataset / task combination.

# %%
from collections import defaultdict
from pyns import Neuroscout
from pathlib import Path
from tools.utils import dump_collection, load_collection
from tools.create import create_single_models
# %matplotlib inline

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Note:</b> To push models to Neuroscout, authenticate pyNS by setting `NEUROSCOUT_USER` and `NEUROSCOUT_PASSWORD` environment variables, or directly passing your auth details to `Neuroscout()`. Google SSO logins are not currently supported.
# </div>

# %%
api = Neuroscout()

# %% [markdown]
# ## Define predictors and confounds

# %%
predictors = ['speech', 'rms', 'text', 'brightness', 'shot_change', 'landscape', 'building', 'tool']
confounds = [
    'a_comp_cor_00', 'a_comp_cor_01', 'a_comp_cor_02', 'a_comp_cor_03', 'a_comp_cor_04', 'a_comp_cor_05', 
    'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z'
]
datasets = api.datasets.get() # Get all Neuroscout datasets

# %% [markdown]
# ## Create models

# %% [markdown]
# The following will create a neuroscout analysis for every dataset/task that and predictor combination.
#
# Uncomment to re-execute and re-create models for the logged in acccount.
#
# <div class="alert alert-block alert-info">
# <b>Note:</b> If a predictor is unavailable for a task, it will be skipped. Examples include visual predictor for auditory narratives, and "shot_change" for NNDb, due to issues with large stimuli in their API
# </div>

# %%
# single_models = create_single_models(predictors, confounds, datasets)

# %%
filename = Path('models') / 'single_predictor.json'

# %%
# Save models out to disk:
# dump_collection(single_mdoels, filename)

# %%
# Load models from cache
single_models = load_collection(filename)

# %%
# Three models for "building" Clarifai visual predictor
single_models['building'][0:3]
# Out:
# [{'dataset': 'Budapest',
#   'task': 'movie',
#   'hash_id': 'A13DD',
#   'analysis': <Analysis hash_id=A13DD name=building dataset_id=27>},
#  {'dataset': 'HealthyBrainNetwork',
#   'task': 'movieDM',
#   'hash_id': 'w0vov',
#   'analysis': <Analysis hash_id=w0vov name=building dataset_id=8>},
#  {'dataset': 'LearningTemporalStructure',
#   'task': 'movie',
#   'hash_id': 'AVrDK',
#   'analysis': <Analysis hash_id=AVrDK name=building dataset_id=19>}]

# %% [markdown]
# We can inspect the BIDS StatsModel generate for any analysis.
#
# For example: `building` for the `Budapest` dataset:

# %%
# BIDS StatsModel generated for a single analysis. 
single_models['building'][0]['analysis'].model
# Out:
# {'Input': {'Run': [1, 2, 3, 4, 5],
#   'Subject': ['sid000021',
#    'sid000535',
#    'sid000055',
#    'sid000052',
#    'sid000025',
#    'sid000029',
#    'sid000120',
#    'sid000024',
#    'sid000278',
#    'sid000005',
#    'sid000499',
#    'sid000522',
#    'sid000007',
#    'sid000114',
#    'sid000030',
#    'sid000020',
#    'sid000142',
#    'sid000416',
#    'sid000050',
#    'sid000013',
#    'sid000009',
#    'sid000034',
#    'sid000010',
#    'sid000134',
#    'sid000560'],
#   'Task': 'movie'},
#  'Name': 'building',
#  'Steps': [{'Contrasts': [],
#    'DummyContrasts': {'Conditions': ['building'], 'Type': 't'},
#    'Level': 'Run',
#    'Model': {'X': ['a_comp_cor_00',
#      'a_comp_cor_01',
#      'a_comp_cor_02',
#      'a_comp_cor_03',
#      'a_comp_cor_04',
#      'a_comp_cor_05',
#      'trans_x',
#      'trans_y',
#      'trans_z',
#      'rot_x',
#      'rot_y',
#      'rot_z',
#      'building']},
#    'Transformations': [{'Input': ['building'], 'Name': 'Convolve'}]},
#   {'DummyContrasts': {'Type': 'FEMA'}, 'Level': 'Subject'},
#   {'DummyContrasts': {'Type': 't'}, 'Level': 'Dataset'}]}

# %% [markdown]
# ## Generate reports

# %% [markdown]
# For every individual analysis created, we can generate reports to inspect the design matrix

# %%
analysis = single_models['building'][0]['analysis']
analysis.generate_report(run_id=analysis.runs[0]) # Only generate for a single example run
# Out:
# {'generated_at': '2022-03-24T21:5',
#  'result': None,
#  'sampling_rate': None,
#  'scale': False,
#  'status': 'PENDING',
#  'traceback': None,
#  'warnings': []}

# %%
analysis.plot_report(plot_type='design_matrix_plot')
# Out:
# <div id="altair-viz-3"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt){
#     const outputDiv = document.getElementById("altair-viz-3");
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.0.0?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = paths[lib];
#         s.async = true;
#         s.onload = () => resolve(paths[lib]);
#         s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#     } else {
#       loadScript("vega")
#         .then(() => loadScript("vega-lite"))
#         .then(() => loadScript("vega-embed"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "config": {"scale": {"bandPaddingInner": 0.0}, "view": {"continuousHeight": 300, "continuousWidth": 400}}, "data": {"name": "data-847a1650f697ee1d2258fa8128c6c083"}, "datasets": {"data-847a1650f697ee1d2258fa8128c6c083": [{"regressor": "building", "scan_number": 0, "value": 0.0004018385698769886}, {"regressor": "building", "scan_number": 1, "value": 0.0009309699704114242}, {"regressor": "building", "scan_number": 2, "value": 0.041037794541038446}, {"regressor": "building", "scan_number": 3, "value": 0.1371733650063253}, {"regressor": "building", "scan_number": 4, "value": 0.2188592803913812}, {"regressor": "building", "scan_number": 5, "value": 0.2780635805929906}, {"regressor": "building", "scan_number": 6, "value": 0.29136799201414626}, {"regressor": "building", "scan_number": 7, "value": 0.2501817616262907}, {"regressor": "building", "scan_number": 8, "value": 0.1983401589632216}, {"regressor": "building", "scan_number": 9, "value": 0.1693316225380392}, {"regressor": "building", "scan_number": 10, "value": 0.16729860971226157}, {"regressor": "building", "scan_number": 11, "value": 0.17597979307038528}, {"regressor": "building", "scan_number": 12, "value": 0.19575347300286075}, {"regressor": "building", "scan_number": 13, "value": 0.2136374372732911}, {"regressor": "building", "scan_number": 14, "value": 0.2115096261137203}, {"regressor": "building", "scan_number": 15, "value": 0.17933088143485063}, {"regressor": "building", "scan_number": 16, "value": 0.1420245339147052}, {"regressor": "building", "scan_number": 17, "value": 0.13935495904986803}, {"regressor": "building", "scan_number": 18, "value": 0.13485415617360524}, {"regressor": "building", "scan_number": 19, "value": 0.1251399385904052}, {"regressor": "building", "scan_number": 20, "value": 0.14499663868086793}, {"regressor": "building", "scan_number": 21, "value": 0.15927643267689642}, {"regressor": "building", "scan_number": 22, "value": 0.15912101638825044}, {"regressor": "building", "scan_number": 23, "value": 0.15780127913124414}, {"regressor": "building", "scan_number": 24, "value": 0.15106090188374627}, {"regressor": "building", "scan_number": 25, "value": 0.13901466774654367}, {"regressor": "building", "scan_number": 26, "value": 0.13054121571965557}, {"regressor": "building", "scan_number": 27, "value": 0.10792762450016119}, {"regressor": "building", "scan_number": 28, "value": 0.08007385740263762}, {"regressor": "building", "scan_number": 29, "value": 0.058971549182432345}, {"regressor": "building", "scan_number": 30, "value": 0.050315259677006174}, {"regressor": "building", "scan_number": 31, "value": 0.0549281694325317}, {"regressor": "building", "scan_number": 32, "value": 0.07300250776221744}, {"regressor": "building", "scan_number": 33, "value": 0.10576639882272522}, {"regressor": "building", "scan_number": 34, "value": 0.1399485088264445}, {"regressor": "building", "scan_number": 35, "value": 0.16681427535363194}, {"regressor": "building", "scan_number": 36, "value": 0.18194011410299138}, {"regressor": "building", "scan_number": 37, "value": 0.18471011713314728}, {"regressor": "building", "scan_number": 38, "value": 0.17678199669699166}, {"regressor": "building", "scan_number": 39, "value": 0.1750869748956441}, {"regressor": "building", "scan_number": 40, "value": 0.18308281099373103}, {"regressor": "building", "scan_number": 41, "value": 0.20459250881880892}, {"regressor": "building", "scan_number": 42, "value": 0.20691016346123156}, {"regressor": "building", "scan_number": 43, "value": 0.16442904456928997}, {"regressor": "building", "scan_number": 44, "value": 0.11246782619769628}, {"regressor": "building", "scan_number": 45, "value": 0.08682877828980368}, {"regressor": "building", "scan_number": 46, "value": 0.08927929742298481}, {"regressor": "building", "scan_number": 47, "value": 0.09260035598805047}, {"regressor": "building", "scan_number": 48, "value": 0.0934336368433343},  ...

# %%
analysis.plot_report(plot_type='design_matrix_corrplot')
# Out:
# <div id="altair-viz-4"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt){
#     const outputDiv = document.getElementById("altair-viz-4");
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.0.0?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = paths[lib];
#         s.async = true;
#         s.onload = () => resolve(paths[lib]);
#         s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#     } else {
#       loadScript("vega")
#         .then(() => loadScript("vega-lite"))
#         .then(() => loadScript("vega-embed"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "config": {"scale": {"bandPaddingInner": 0.015}, "view": {"continuousHeight": 300, "continuousWidth": 400, "strokeWidth": 0}}, "data": {"name": "data-faa9815fc30f840a86ef4b8fb319cf12"}, "datasets": {"data-faa9815fc30f840a86ef4b8fb319cf12": [{"index": "building", "index_2": "building", "r": 1.0}, {"index": "a_comp_cor_00", "index_2": "building", "r": null}, {"index": "a_comp_cor_01", "index_2": "building", "r": null}, {"index": "a_comp_cor_02", "index_2": "building", "r": null}, {"index": "a_comp_cor_03", "index_2": "building", "r": null}, {"index": "a_comp_cor_04", "index_2": "building", "r": null}, {"index": "a_comp_cor_05", "index_2": "building", "r": null}, {"index": "rot_x", "index_2": "building", "r": null}, {"index": "rot_y", "index_2": "building", "r": null}, {"index": "rot_z", "index_2": "building", "r": null}, {"index": "trans_x", "index_2": "building", "r": null}, {"index": "trans_y", "index_2": "building", "r": null}, {"index": "trans_z", "index_2": "building", "r": null}, {"index": "building", "index_2": "a_comp_cor_00", "r": 0.011766097494990838}, {"index": "a_comp_cor_00", "index_2": "a_comp_cor_00", "r": 1.0}, {"index": "a_comp_cor_01", "index_2": "a_comp_cor_00", "r": null}, {"index": "a_comp_cor_02", "index_2": "a_comp_cor_00", "r": null}, {"index": "a_comp_cor_03", "index_2": "a_comp_cor_00", "r": null}, {"index": "a_comp_cor_04", "index_2": "a_comp_cor_00", "r": null}, {"index": "a_comp_cor_05", "index_2": "a_comp_cor_00", "r": null}, {"index": "rot_x", "index_2": "a_comp_cor_00", "r": null}, {"index": "rot_y", "index_2": "a_comp_cor_00", "r": null}, {"index": "rot_z", "index_2": "a_comp_cor_00", "r": null}, {"index": "trans_x", "index_2": "a_comp_cor_00", "r": null}, {"index": "trans_y", "index_2": "a_comp_cor_00", "r": null}, {"index": "trans_z", "index_2": "a_comp_cor_00", "r": null}, {"index": "building", "index_2": "a_comp_cor_01", "r": -0.00772336924424109}, {"index": "a_comp_cor_00", "index_2": "a_comp_cor_01", "r": 4.663541151962519e-07}, {"index": "a_comp_cor_01", "index_2": "a_comp_cor_01", "r": 1.0}, {"index": "a_comp_cor_02", "index_2": "a_comp_cor_01", "r": null}, {"index": "a_comp_cor_03", "index_2": "a_comp_cor_01", "r": null}, {"index": "a_comp_cor_04", "index_2": "a_comp_cor_01", "r": null}, {"index": "a_comp_cor_05", "index_2": "a_comp_cor_01", "r": null}, {"index": "rot_x", "index_2": "a_comp_cor_01", "r": null}, {"index": "rot_y", "index_2": "a_comp_cor_01", "r": null}, {"index": "rot_z", "index_2": "a_comp_cor_01", "r": null}, {"index": "trans_x", "index_2": "a_comp_cor_01", "r": null}, {"index": "trans_y", "index_2": "a_comp_cor_01", "r": null}, {"index": "trans_z", "index_2": "a_comp_cor_01", "r": null}, {"index": "building", "index_2": "a_comp_cor_02", "r": -0.034900171740578564}, {"index": "a_comp_cor_00", "index_2": "a_comp_cor_02", "r": 1.4247154968603218e-06}, {"index": "a_comp_cor_01", "index_2": "a_comp_cor_02", "r": -4.894717494201288e-07}, {"index": "a_comp_cor_02", "index_2": "a_comp_cor_02", "r": 1.0}, {"index": "a_comp_cor_03", "index_2": "a_comp_cor_02", "r": null}, {"index": "a_comp_cor_04", "index_2": "a_comp_cor_02", "r": null}, {"index": "a_comp_cor_05", "index_2": "a_comp_cor_02", "r": null}, {"index": "rot_x", "index_2": "a_comp_cor_02", "r": null}, {"index": "rot_y", "index_2": "a_comp_cor_02", "r": null}, {"index": "rot_z", "index_2": "a_comp_cor_02", "r": null}, {"index": "trans_x", "index_2": "a_comp_cor_02", "r": null}, {"index": "trans_y", "index_2": "a_comp_cor_02", "r": null}, {"index": "trans_z", "index_2": "a_comp_cor_02", "r": null}, {"index": "building", "index_2": "a_comp_cor_03", "r": 0.008806457328189222}, {"index": "a_comp_cor_00", "index_2": "a_comp_cor_03", "r": 9.601968264658699e-07}, {"index": "a_comp_cor_01", "index_2": "a_comp_cor_03", "r": -4.3304138796397127e-07}, {"index": "a_comp_cor_02", "index_2": "a_comp_cor_03", "r": -3.0898215354636365e-07}, {"index": "a_comp_cor_03 ...

# %% [markdown]
# ## Compile models

# %% [markdown]
# The following will "compile" every created model, validating the model and producing an executable bundle

# %%
for pred, models in single_models.items():
    for model in models:
        # If analysis is still in "DRAFT" model, compile it.
        if model['analysis'].get_status()['status'] == 'DRAFT':
            model['analysis'].compile()

# %% [markdown]
# ## Model Execution

# %% [markdown]
# Models can be executed using Neuroscout-CLI. For more information see the [Neuroscout documentation](https://neuroscout.github.io/neuroscout/cli/).
#
# For example, to re-run the following model using Docker:

# %%
single_models['building'][0]
# Out:
# {'dataset': 'Budapest',
#  'task': 'movie',
#  'hash_id': 'A13DD',
#  'analysis': <Analysis hash_id=A13DD name=building dataset_id=27>}

# %% [markdown]
# Use the following command:
#
# ```
# docker run --rm -it -v /home/results/:/out neuroscout/neuroscout-cli run --force-upload A13DD /out
# ```
#
# This will download the bundle for `M8LYl`, the necessary preprocessed imaging data from the `Budapest` dataset, run the analysis workflow and upload results to NeuroVault (even if an upload already exists).
#
# <div class="alert alert-block alert-info">
# <b>Note:</b> Replace `/home/results` with a real directory in your local environment
# </div>

# %% [markdown]
# # Results

# %%
DOWNLOAD_DIR = Path('./images')

# %% [markdown]
# All single dataset results are indexed by Neuroscout, and the resulting statistical images are archived in NeuroVault.

# %%
analysis = single_models['building'][0]['analysis'] # Budapest analysis for "building"
analysis.hash_id
# Out:
# 'A13DD'

# %% [markdown]
# We can view this analysis and the associated uploads using Neuroscout's website at this URL: https://neuroscout.org/builder/A13DD
#
# Alternatively, we can download the associated images and display them like so.
#
# This will download the images matching `image_filters` for the latest associated NeuroVault collection and plot the results using `nilearn.plotting`

# %%
analysis.plot_uploads(download_dir=DOWNLOAD_DIR, 
                      image_filters={'stat': 't', 'space': 'MNI152NLin2009cAsym'}, 
                      plot_args={'threshold':3})

# %% [markdown]
# ### Figure 4
# In Figure 4, we convert the t maps to z maps, and plot using nilearn on a grid

# %%
from nilearn.glm import threshold_stats_img
from nilearn.plotting import plot_stat_map
import matplotlib.pyplot as plt
from tools.utils import t_to_z

# %%
plot_args = dict(colorbar=False, display_mode='z', cut_coords=[-12], vmax=15, annotate=False)
contrast = 'building'

fig, axs = plt.subplots(ncols=4, nrows=1, figsize=(20, 8))

i = 0
for an in single_models[contrast]:
    # Only plot for 4 tasks
    if an['task'] in ['SherlockMovie', 'movie', '500daysofsummer'] and an['dataset'] not in ['studyforrest']:
        ax = axs[i]
        i += 1
        # Download images matching filters
        t_map, metadata = an['analysis'].load_uploads(
                image_filters={'stat': 't', 'space': 'MNI152NLin2009cAsym'}, 
                download_dir=DOWNLOAD_DIR)[0]
        
        # Convert to Z maps, and compute threshold at p<0.001
        n_subjects = len(an['analysis'].model['Input']['Subject'])
        z_map = t_to_z(t_map, n_subjects-1)
        thresh_z_map, thresh = threshold_stats_img(z_map, alpha=0.001)
        
        # Plot
        plot_stat_map(thresh_z_map, threshold=thresh, title=f"{an['dataset']}", **plot_args, axes=ax)

# %%
plot_args = dict(colorbar=False, display_mode='z', cut_coords=[-10], vmax=15, annotate=False)
contrast = 'text'
fig, axs = plt.subplots(ncols=4, nrows=1, figsize=(20, 8))

i = 0

for an in single_models[contrast]:
    if an['task'] in ['SherlockMovie', 'movie', '500daysofsummer'] and an['dataset'] not in ['studyforrest']:
        ax = axs[i]
        i += 1
        t_map, metadata = an['analysis'].load_uploads(
                image_filters={'stat': 't', 'space': 'MNI152NLin2009cAsym'}, 
                download_dir=DOWNLOAD_DIR)[0]
        n_subjects = len(an['analysis'].model['Input']['Subject'])
        z_map = t_to_z(t_map, n_subjects-1)
        thresh_z_map, thresh = threshold_stats_img(z_map, alpha=0.001)
        plot_stat_map(thresh_z_map, threshold=thresh, **plot_args, title=f"{an['dataset']}", axes=ax)

# %%
plot_args = dict(colorbar=False, display_mode='z', cut_coords=[6], vmax=15, annotate=False)
contrast = 'rms'
fig, axs = plt.subplots(ncols=4, nrows=1, figsize=(20, 8))

i = 0

for an in single_models[contrast]:
    if an['task'] in ['SherlockMovie', 'movie', '500daysofsummer'] and an['dataset'] not in ['studyforrest']:
        ax = axs[i]
        i += 1
        t_map, metadata = an['analysis'].load_uploads(
                image_filters={'stat': 't', 'space': 'MNI152NLin2009cAsym'}, 
                download_dir=DOWNLOAD_DIR)[0]
        n_subjects = len(an['analysis'].model['Input']['Subject'])
        z_map = t_to_z(t_map, n_subjects-1)
        thresh_z_map, thresh = threshold_stats_img(z_map, alpha=0.001)
        plot_stat_map(thresh_z_map, threshold=thresh, **plot_args, title=f"{an['dataset']}", axes=ax)
