# %% [markdown]
# # New Audio Models

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tools.create import create_single_models, create_set_models
from tools.base import (dump_collection, load_collection, 
                        flatten_collection, compute_metrics,
                        _extract_regressors)
from tools.viz import (plot_regressor,
                       plot_metrics, plot_contrast_by_dataset, plot_contrast_by_analysis,
                       plot_analysis_grid)
from pyns import Neuroscout
import numpy as np
from matplotlib import pyplot as plt
from pathlib import Path
# %matplotlib inline

# %%
api = Neuroscout()

# %% [markdown]
# ## Define predictors and confounds

# %%
rmslist = ['rms']
tonal = ['tonal_centroid_0', 'tonal_centroid_1', 'tonal_centroid_2', 'tonal_centroid_3', 'tonal_centroid_4', 'tonal_centroid_5']

# %%
confounds = ['a_comp_cor_00', 'a_comp_cor_01', 'a_comp_cor_02', 'a_comp_cor_03', 'a_comp_cor_04', 'a_comp_cor_05', 'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z']

# %% [markdown]
# ## Create models

# %%
#single_models = create_single_models(rmslist, confounds)
#tonal_models = create_set_models(tonal, confounds, name='tonnetz')
tonal_rms_models = create_set_models(tonal+rmslist, confounds, name='+'.join(tonal+rmslist))

# %%
#fname = Path('models') / 'new_rms.json'
#fname_tonal = Path('models') / 'tonal.json'
fname_tonal_rms = Path('models') / 'tonal_rms.json'

# %%
#dump_collection(single_models, fname)
dump_collection(tonal_rms_models, fname_tonal_rms)
#dump_collection(tonal_models, fname_tonal)

# %%
#single_models = load_collection(fname)
#tonal_models = load_collection(fname_tonal)
tonal_rms_models = load_collection(fname_tonal_rms)

# %%
#tonal_models = {'+'.join(tonal): tonal_models}
tonal_rms_models = {'+'.join(tonal+rmslist): tonal_rms_models}

# %%
cdict = {"Name": "any_tonnetz",
         "ConditionList": tonal,
         "Weights": np.eye(len(tonal)).astype(int).tolist(),
         "Type": "F"}

# %%
cdict = {"Name": "any_tonnetz",
         "ConditionList": tonal,
         "Weights": np.eye(len(tonal)).astype(int).tolist(),
         "Type": "F"}
for (pred, ds, task), analysis in flatten_collection(tonal_rms_models):
    analysis.model['Steps'][2]['Contrasts'] = [cdict]
    analysis.push()

# %% [markdown]
# ## Generate reports

# %%
for (pred, dataset, task), model in flatten_collection(single_models)[:2]:
    model.generate_report(run_id=model.runs[0])

# %%
for (pred, dataset, task), model in flatten_collection(tonal_models)[:2]:
    model.generate_report(run_id=model.runs[0])

# %%
for (pred, dataset, task), model in flatten_collection(tonal_rms_models)[:2]:
    model.generate_report(run_id=model.runs[0])

# %%
for p in rmslist:
    single_models[p]['Budapest']['movie'].plot_report()
# Out:
# <div id="altair-viz-5db7250f84a94370babc29a32b21cfe6"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-5db7250f84a94370babc29a32b21cfe6") {
#       outputDiv = document.getElementById("altair-viz-5db7250f84a94370babc29a32b21cfe6");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.8.1?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = paths[lib];
#         s.async = true;
#         s.onload = () => resolve(paths[lib]);
#         s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#     } else {
#       loadScript("vega")
#         .then(() => loadScript("vega-lite"))
#         .then(() => loadScript("vega-embed"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "config": {"scale": {"bandPaddingInner": 0.0}, "view": {"continuousHeight": 300, "continuousWidth": 400}}, "data": {"name": "data-5ae997bdb34717cadcaf375fd6bdc3f2"}, "datasets": {"data-5ae997bdb34717cadcaf375fd6bdc3f2": [{"regressor": "rms", "scan_number": 0, "value": -0.49920738006844867}, {"regressor": "rms", "scan_number": 1, "value": -0.4992073771335578}, {"regressor": "rms", "scan_number": 2, "value": -0.49920738063120423}, {"regressor": "rms", "scan_number": 3, "value": -0.4992073825301992}, {"regressor": "rms", "scan_number": 4, "value": -0.49920734891960167}, {"regressor": "rms", "scan_number": 5, "value": -0.499207509590282}, {"regressor": "rms", "scan_number": 6, "value": -0.4992069082817217}, {"regressor": "rms", "scan_number": 7, "value": -0.4992089315492179}, {"regressor": "rms", "scan_number": 8, "value": -0.4992024269954159}, {"regressor": "rms", "scan_number": 9, "value": -0.4992209469319195}, {"regressor": "rms", "scan_number": 10, "value": -0.49918259019355127}, {"regressor": "rms", "scan_number": 11, "value": -0.4988442627687876}, {"regressor": "rms", "scan_number": 12, "value": -0.4892961407512405}, {"regressor": "rms", "scan_number": 13, "value": -0.4489164098582809}, {"regressor": "rms", "scan_number": 14, "value": -0.37072220759924024}, {"regressor": "rms", "scan_number": 15, "value": -0.2786450613227596}, {"regressor": "rms", "scan_number": 16, "value": -0.19756044206945292}, {"regressor": "rms", "scan_number": 17, "value": -0.13426158617491307}, {"regressor": "rms", "scan_number": 18, "value": -0.08142471243672854}, {"regressor": "rms", "scan_number": 19, "value": -0.03715167490687533}, {"regressor": "rms", "scan_number": 20, "value": -0.009312427507701728}, {"regressor": "rms", "scan_number": 21, "value": 0.0058178708798576955}, {"regressor": "rms", "scan_number": 22, "value": 0.01481817264416624}, {"regressor": "rms", "scan_number": 23, "value": 0.023478581128329692}, {"regressor": "rms", "scan_number": 24, "value": 0.041317991280924594}, {"regressor": "rms", "scan_number": 25, "value": 0.0725861849484877}, {"regressor": "rms", "scan_number": 26, "value": 0.11620237210740084}, {"regressor": "rms", "scan_number": 27, "value": 0.1622356417882174}, {"regressor": "rms", "scan_number": 28, "value": 0.19364497546521933}, {"regressor": "rms", "scan_number": 29, "value": 0.2025322279780619}, {"regressor": "rms", "scan_number": 30, "value": 0.19641026335139256}, {"regressor": "rms", "scan_number": 31, "value": 0.18871154302617207}, {"regressor": "rms", "scan_number": 32, "value": 0.198030498894952}, {"regressor": "rms", "scan_number": 33, "value": 0.22824117426670387}, {"regressor": "rms", "scan_number": 34, "value": 0.26104999129860484}, {"regressor": "rms", "scan_number": 35, "value": 0.2856554235947356}, {"regressor": "rms", "scan_number": 36, "value": 0.30129620908939514}, {"regressor": "rms", "scan_number": 37, "value": 0.30917472987785183}, {"regressor": "rms", "scan_number": 38, "value": 0.3143852452230453}, {"regressor": "rms", "scan_number": 39, "value": 0.32099124194699896}, {"regressor": "rms", "scan_number": 40, "value": 0.32630204297684645}, {"regressor": "rms", "scan_number": 41, "value": 0.32617190828074855}, {"regressor": "rms", "scan_number": 42, "value": 0.31309973100111926}, {"regressor": "rms", "scan_number": 43, "value": 0.2706585785968249}, {"regressor": "rms", "scan_number": 44, "value": 0.20123254346155903}, {"regressor": "rms", "scan_number": 45, "value": 0.1308320527787666}, {"regressor": "rms", "scan_number": 46, "value": 0.07393256537133071}, {"regressor": "rms", "scan_number": 47, "value": 0.028506152351456378}, {"regressor": "rms", "scan_number": 48, "value": -0.0038643107612881043}, {"regressor": "rms", "scan_number": 49, "value": -0.035912277081252504}, {"regressor": "rms", "scan_number": 50, "value": -0.0743137101267446}, {"regressor": "rms", "scan_number": 51, "value": -0.1034939952868867}, {"regressor":  ...

# %%
tonal_rms_models['+'.join(tonal+rmslist)]['Budapest']['movie'].plot_report()
# Out:
# <div id="altair-viz-f0b1eb2ef1084bfc8103724b1cccfb8f"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-f0b1eb2ef1084bfc8103724b1cccfb8f") {
#       outputDiv = document.getElementById("altair-viz-f0b1eb2ef1084bfc8103724b1cccfb8f");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.8.1?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = paths[lib];
#         s.async = true;
#         s.onload = () => resolve(paths[lib]);
#         s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#     } else {
#       loadScript("vega")
#         .then(() => loadScript("vega-lite"))
#         .then(() => loadScript("vega-embed"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "config": {"scale": {"bandPaddingInner": 0.0}, "view": {"continuousHeight": 300, "continuousWidth": 400}}, "data": {"name": "data-8b198dcaa32f7325219bd5a6c74a1002"}, "datasets": {"data-8b198dcaa32f7325219bd5a6c74a1002": [{"regressor": "tonal_centroid_0", "scan_number": 0, "value": 0.00189164152033412}, {"regressor": "tonal_centroid_0", "scan_number": 1, "value": 0.0018916461559732652}, {"regressor": "tonal_centroid_0", "scan_number": 2, "value": 0.0018916314461881907}, {"regressor": "tonal_centroid_0", "scan_number": 3, "value": 0.0018916759056388528}, {"regressor": "tonal_centroid_0", "scan_number": 4, "value": 0.0018915462856909566}, {"regressor": "tonal_centroid_0", "scan_number": 5, "value": 0.001891913460087628}, {"regressor": "tonal_centroid_0", "scan_number": 6, "value": 0.0018908983229850352}, {"regressor": "tonal_centroid_0", "scan_number": 7, "value": 0.0018936486651117295}, {"regressor": "tonal_centroid_0", "scan_number": 8, "value": 0.0018863079837805456}, {"regressor": "tonal_centroid_0", "scan_number": 9, "value": 0.0019049675669129966}, {"regressor": "tonal_centroid_0", "scan_number": 10, "value": 0.0018636169877195373}, {"regressor": "tonal_centroid_0", "scan_number": 11, "value": 0.001861479925690987}, {"regressor": "tonal_centroid_0", "scan_number": 12, "value": -0.001377533309076782}, {"regressor": "tonal_centroid_0", "scan_number": 13, "value": -0.01232184731021247}, {"regressor": "tonal_centroid_0", "scan_number": 14, "value": -0.011764812102206248}, {"regressor": "tonal_centroid_0", "scan_number": 15, "value": 0.025908975728657014}, {"regressor": "tonal_centroid_0", "scan_number": 16, "value": 0.09155117066171682}, {"regressor": "tonal_centroid_0", "scan_number": 17, "value": 0.1449145870253985}, {"regressor": "tonal_centroid_0", "scan_number": 18, "value": 0.14675624433511425}, {"regressor": "tonal_centroid_0", "scan_number": 19, "value": 0.09035322364322909}, {"regressor": "tonal_centroid_0", "scan_number": 20, "value": 0.001640956085137328}, {"regressor": "tonal_centroid_0", "scan_number": 21, "value": -0.07154747647538627}, {"regressor": "tonal_centroid_0", "scan_number": 22, "value": -0.10559826874633761}, {"regressor": "tonal_centroid_0", "scan_number": 23, "value": -0.10568571372161453}, {"regressor": "tonal_centroid_0", "scan_number": 24, "value": -0.08730350127054129}, {"regressor": "tonal_centroid_0", "scan_number": 25, "value": -0.06697678060741535}, {"regressor": "tonal_centroid_0", "scan_number": 26, "value": -0.04907165072949406}, {"regressor": "tonal_centroid_0", "scan_number": 27, "value": -0.04384155459996334}, {"regressor": "tonal_centroid_0", "scan_number": 28, "value": -0.07273428434628114}, {"regressor": "tonal_centroid_0", "scan_number": 29, "value": -0.1279086366205889}, {"regressor": "tonal_centroid_0", "scan_number": 30, "value": -0.17715087518119557}, {"regressor": "tonal_centroid_0", "scan_number": 31, "value": -0.2033443379931575}, {"regressor": "tonal_centroid_0", "scan_number": 32, "value": -0.18753952974278462}, {"regressor": "tonal_centroid_0", "scan_number": 33, "value": -0.0960648947312254}, {"regressor": "tonal_centroid_0", "scan_number": 34, "value": 0.04485835321783045}, {"regressor": "tonal_centroid_0", "scan_number": 35, "value": 0.1742245688161269}, {"regressor": "tonal_centroid_0", "scan_number": 36, "value": 0.2576563708420479}, {"regressor": "tonal_centroid_0", "scan_number": 37, "value": 0.2938270378743131}, {"regressor": "tonal_centroid_0", "scan_number": 38, "value": 0.2991781647874113}, {"regressor": "tonal_centroid_0", "scan_number": 39, "value": 0.28718356381163695}, {"regressor": "tonal_centroid_0", "scan_number": 40, "value": 0.2644977498030379}, {"regressor": "tonal_centroid_0", "scan_number": 41, "value": 0.2385773297711129}, {"regressor": "tonal_centroid_0", "scan_number": 42, "value": 0.21614488199744958}, {"regressor": "tonal_centroid_0", "scan_number": 43, "value": 0.19715081427 ...
# 'OK'

# %% [markdown]
# ## Inspect regressors

# %%
df = _extract_regressors(single_models)

# %%
plot_regressor_distribution(df=df, split_by='hue', color=None, aspect=3, hist=None, rug=True)

# %%
plot_regressor_timeseries(df=df, split_by='row', height=1.2, aspect=10)

# %%
agg_df = compute_metrics(df=df, aggfunc=[np.mean, np.std, np.var])

# %%
plot_metrics(agg_df, metrics=['mean', 'std', 'var'],
             sns_function='barplot', height=3, aspect=1)

# %% [markdown]
# ## Compile models

# %%
for (pred, dataset, task), model in flatten_collection(single_models):
    if model.get_status()['status'] == 'DRAFT':
        model.private = False
        model.push()
        model.compile()
    else:
        print(f'{pred} {model.status} for {dataset}')
# Out:
# rms PASSED for Budapest
# rms PASSED for HealthyBrainNetwork
# rms PASSED for LearningTemporalStructure
# rms PASSED for Life
# rms PASSED for ParanoiaStory
# rms PASSED for Raiders
# rms PASSED for SchematicNarrative
# rms PASSED for Sherlock
# rms PASSED for SherlockMerlin
# rms PASSED for SherlockMerlin
# rms PASSED for studyforrest

# %%
for (pred, dataset, task), model in flatten_collection(tonal_models):
    if model.get_status()['status'] == 'DRAFT':
        model.private = False
        model.push()
        model.compile()
    else:
        print(f'tonal models {model.status} for {dataset}')
# Out:
# tonal models PASSED for Budapest
# tonal models PASSED for HealthyBrainNetwork
# tonal models PASSED for LearningTemporalStructure
# tonal models PASSED for Life
# tonal models PASSED for ParanoiaStory
# tonal models PASSED for Raiders
# tonal models PASSED for SchematicNarrative
# tonal models PASSED for Sherlock
# tonal models PASSED for SherlockMerlin
# tonal models PASSED for SherlockMerlin
# tonal models PASSED for studyforrest

# %%
for (pred, dataset, task), model in flatten_collection(tonal_rms_models):
    if model.get_status()['status'] == 'DRAFT':
        model.private = False
        model.push()
        model.compile()
    else:
        print(f'tonal models {model.status} for {dataset}')
# Out:
# tonal models PASSED for Budapest
# tonal models PASSED for HealthyBrainNetwork
# tonal models PASSED for LearningTemporalStructure
# tonal models PASSED for Life
# tonal models PASSED for ParanoiaStory
# tonal models PASSED for Raiders
# tonal models PASSED for SchematicNarrative
# tonal models PASSED for Sherlock
# tonal models PASSED for SherlockMerlin
# tonal models PASSED for SherlockMerlin
# tonal models PASSED for studyforrest

# %%
' '.join([a[1].hash_id for a in flatten_collection(single_models)])
# Out:
# '8ytxy fb9ak ro5d2 fdstd qy8r8 oku9e dth7h njw6g 9z593 6ijx5 dsugf'

# %%
' '.join([a[1].hash_id for a in flatten_collection(tonal_models)])
# Out:
# 'g5wfg g3q54 8ms8a oa4hv sesis oiru3 ge7ot n654u eef5u egwhj h84ju'

# %%
' '.join([a[1].hash_id for a in flatten_collection(tonal_rms_models)])
# Out:
# '9fynr nz9mk asmhi kcvwg g6idn myqti b66t8 ng32p 7aij7 no3v4 k5aou'

# %% [markdown]
# ## Results

# %%
flat_models = flatten_collection(single_models)
flat_models_tonal = flatten_collection(tonal_models)
flat_models_tonal_rms = flatten_collection(tonal_rms_models)

# %%
plt.rcParams.update({'font.family': 'monospace'})
plot_contrast_by_analysis(flat_models_tonal,
                          vmax=10, display_mode='z', figsize=(12,15),
                          threshold=1.96, colorbar=False)

# %%
plt.rcParams.update({'font.family': 'monospace'})
plot_contrast_by_analysis(flat_models_tonal,
                          vmax=10, display_mode='z', figsize=(12,15),
                          threshold=1.96, colorbar=False)

# %%
plt.rcParams.update({'font.family': 'monospace'})
plot_contrast_by_analysis(flat_models_tonal_rms,
                          vmax=10, display_mode='z', figsize=(12,15),
                          threshold=1.96, colorbar=False)
