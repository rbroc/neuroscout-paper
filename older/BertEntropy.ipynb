# %% [markdown]
# # Bert Entropy
# Single-predictor models with entropy on BERT language model predictions

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline
from tools.create import create_single_models, create_set_models
from tools.base import (dump_collection, load_collection, 
                        flatten_collection, compute_metrics,
                        _extract_regressors)
from pyns import Neuroscout
import numpy as np
from matplotlib import pyplot as plt
from pathlib import Path
from tools.viz import plot_contrast_by_analysis

# %%
api = Neuroscout()

# %% [markdown]
# ## Create and compile

# %%
transformations = [{"Name": "Scale", 
                    "Demean": True, 
                    "Rescale": True,
                    "ReplaceNA": "after", 
                    "Input": ["BERTLM_pre_25_entropy"]}]

# %%
# Note that this will include cosine* and nonsteadstate* for all runs that fitlins finds them for, dynamically
confounds = ['a_comp_cor_00', 'a_comp_cor_01', 'a_comp_cor_02', 'a_comp_cor_03', 'a_comp_cor_04', 'a_comp_cor_05', 
             'trans_x', 'trans_y', 'trans_z', 'rot_x', 'rot_y', 'rot_z']

# %%
single_models = create_single_models(["BERTLM_pre_25_entropy"], confounds, transformations=transformations)

# %%
dump_collection(single_models, 'models/bert_entropy.json')

# %%
single_models = load_collection('models/bert_entropy.json')

# %% [markdown]
# ### Reports

# %%
""" Run reports for all models """
for (pred, dataset, task), model in flatten_collection(single_models):
    model.generate_report(run_id=model.runs[0])

# %%
# Plot example design matrix
single_models['BERTLM_pre_25_entropy']['Budapest']['movie'].plot_report()
# Out:
# <div id="altair-viz-9d2aa2c802c54d71818ddaaa3a24f2c5"></div>
# <script type="text/javascript">
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-9d2aa2c802c54d71818ddaaa3a24f2c5") {
#       outputDiv = document.getElementById("altair-viz-9d2aa2c802c54d71818ddaaa3a24f2c5");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm//vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm//vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm//vega-lite@4.8.1?noext",
#       "vega-embed": "https://cdn.jsdelivr.net/npm//vega-embed@6?noext",
#     };
#
#     function loadScript(lib) {
#       return new Promise(function(resolve, reject) {
#         var s = document.createElement('script');
#         s.src = paths[lib];
#         s.async = true;
#         s.onload = () => resolve(paths[lib]);
#         s.onerror = () => reject(`Error loading script: ${paths[lib]}`);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       });
#     }
#
#     function showError(err) {
#       outputDiv.innerHTML = `<div class="error" style="color:red;">${err}</div>`;
#       throw err;
#     }
#
#     function displayChart(vegaEmbed) {
#       vegaEmbed(outputDiv, spec, embedOpt)
#         .catch(err => showError(`Javascript Error: ${err.message}<br>This usually means there's a typo in your chart specification. See the javascript console for the full traceback.`));
#     }
#
#     if(typeof define === "function" && define.amd) {
#       requirejs.config({paths});
#       require(["vega-embed"], displayChart, err => showError(`Error loading script: ${err.message}`));
#     } else if (typeof vegaEmbed === "function") {
#       displayChart(vegaEmbed);
#     } else {
#       loadScript("vega")
#         .then(() => loadScript("vega-lite"))
#         .then(() => loadScript("vega-embed"))
#         .catch(showError)
#         .then(() => displayChart(vegaEmbed));
#     }
#   })({"$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json", "config": {"scale": {"bandPaddingInner": 0.0}, "view": {"continuousHeight": 300, "continuousWidth": 400}}, "data": {"name": "data-9659f81f8ba5749ca701b7d6e255f495"}, "datasets": {"data-9659f81f8ba5749ca701b7d6e255f495": [{"regressor": "BERTLM_pre_25_entropy", "scan_number": 0, "value": -0.01439426755434213}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 1, "value": -0.014394267556162469}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 2, "value": -0.014394267551578348}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 3, "value": -0.014394267562877129}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 4, "value": -0.014394267535691327}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 5, "value": -0.01439426759927146}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 6, "value": -0.014394267455755862}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 7, "value": -0.014394267764623842}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 8, "value": -0.014394267145377455}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 9, "value": -0.014394268243010109}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 10, "value": -0.014394266786030249}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 11, "value": -0.014394266843325232}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 12, "value": -0.01439427646639581}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 13, "value": -0.014394226342983095}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 14, "value": -0.014394419861053285}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 15, "value": -0.014393760985614729}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 16, "value": -0.014395850825156252}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 17, "value": -0.014389510187351592}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 18, "value": -0.01440777338902168}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 19, "value": -0.014359930041146657}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 20, "value": -0.014424018652931444}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 21, "value": -0.012432497213516617}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 22, "value": -0.008231471665206139}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 23, "value": -0.001976244987083181}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 24, "value": 0.007289023691090025}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 25, "value": 0.0015228480861691704}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 26, "value": -0.032724683759433694}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 27, "value": -0.06897570883415666}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 28, "value": -0.0687861455733536}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 29, "value": -0.03933760988592318}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 30, "value": -0.007875221587732864}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 31, "value": 0.010814830636238306}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 32, "value": 0.016066860000777467}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 33, "value": 0.013213258040599389}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 34, "value": 0.007376587710283085}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 35, "value": 0.0015044529748560584}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 36, "value": -0.003342607711669895}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 37, "value": -0.007094123580535018}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 38, "value": -0.009981822239916442}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 39, "value": -0.012213504573910898}, {"regressor": "BERTLM_pre_25_entropy", "scan_number": 40, "value": -0.013897639921331648}, ...
# 'OK'

# %% [markdown]
# ### Compile

# %%
for (pred, dataset, task), model in flatten_collection(single_models):
    if model.get_status()['status'] == 'DRAFT':
        model.private = False
        model.compile()
    else:
        print(f'{model.status}')
        print(f'{dataset}')
# Out:
# PASSED
# Budapest
# PASSED
# HealthyBrainNetwork
# PASSED
# LearningTemporalStructure
# PASSED
# Life
# PASSED
# ParanoiaStory
# PASSED
# Raiders
# PASSED
# Sherlock
# PASSED
# SherlockMerlin
# PASSED
# SherlockMerlin

# %%
print(' '.join([model.hash_id for (pred, dataset, task), model in flatten_collection(single_models)]))
# Out:
# wJ324 MNQGZ wy2Wd 9eyVk AZ4E2 M55kP Mv3Xb Mm3K3 MpDzb

# %% [markdown]
# ## Results

# %%
flat_models = flatten_collection(single_models)

# %%
plt.rcParams.update({'font.family': 'monospace'})
plot_contrast_by_analysis(analyses=flat_models,
                         contrasts=['BERTLM_pre_25_entropy'],
                         vmax=10, display_mode='z', figsize=(15,15),
                         threshold=1.96, colorbar=False)
